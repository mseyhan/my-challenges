# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
league_index = {"1":"prem","2":"superlig"} # considering there will be other league datas in the future, i'd like to design an holistic program for all

que = input("Submit 1 for Premier League, 2 for Super League:")

# %%
matchdata = pd.read_csv("../footballdata/{:}/2019-2020.csv".format(league_index[que])) #read the csv data from the related directory and format the file name with a variable to make the program understand the changes in league coices

real_cols = matchdata.columns.to_list()
col_names = []
info = open("../footballdata/notes football data.txt").readlines() # read the metadata to find the column name
print(real_cols)
# Out:
# ['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA', 'B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA', 'IWCH', 'IWCD', 'IWCA', 'PSCH', 'PSCD', 'PSCA', 'WHCH', 'WHCD', 'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH', 'AvgCD', 'AvgCA', 'B365C>2.5', 'B365C<2.5', 'PC>2.5', 'PC<2.5', 'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA', 'AvgCAHH', 'AvgCAHA']

# %%
# knowing the structure of the txt metadata, there are some explanations about the column names so we will be obtaining these as our column names and appending to col_names in the for structure
for line in info:
    str_line = str(line)
    #print(str_line)
    finder = re.findall(r"(^\w*).*=",str_line)
    if len(finder) >= 1 and finder[0] in real_cols :
        #print(finder[0])
        col_names.append(finder[0])

# %%
count_until = col_names.index("AR")+1 # i don't need bet values or any odds so i made a variable for the index of the last column i'm gonna be working with

# %%
#while rearranging matchdata, we used the same format structure but we used the columns that we already found out in metadata and sliced the col_names list and shaved the list as we wished
matchdata = pd.read_csv("../footballdata/{:}/2019-2020.csv".format(league_index[que]),usecols=col_names[:count_until]) 
#the date and time columns are seperated and they dont seem to be "datetime64" format, so we'll be joining them together and rearranging the format so in the future we can sort by the date. 
# For example we can parse the data starting from lockdown in pandemic then see the effect of pandemic to some sorta stuff
matchdata["Date"] = [" ".join(value) for value in zip(matchdata["Date"],matchdata["Time"])]
matchdata["Date"] = pd.to_datetime(matchdata["Date"])
matchdata.drop("Time",axis=1,inplace=True) #dropped the time column, we dont need it anymore

# %%
print(real_cols)
# Out:
# ['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA', 'B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA', 'IWCH', 'IWCD', 'IWCA', 'PSCH', 'PSCD', 'PSCA', 'WHCH', 'WHCD', 'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH', 'AvgCD', 'AvgCA', 'B365C>2.5', 'B365C<2.5', 'PC>2.5', 'PC<2.5', 'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA', 'AvgCAHH', 'AvgCAHA']

# %%
print(col_names)
# Out:
# ['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA']

# %%
print(matchdata.head(10))
print(matchdata.info())
# Out:
#   Div                Date        HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 0  E0 2019-09-08 20:00:00       Liverpool           Norwich     4     1   H
# 1  E0 2019-10-08 12:30:00        West Ham          Man City     0     5   A
# 2  E0 2019-10-08 15:00:00     Bournemouth  Sheffield United     1     1   D
# 3  E0 2019-10-08 15:00:00         Burnley       Southampton     3     0   H
# 4  E0 2019-10-08 15:00:00  Crystal Palace           Everton     0     0   D
# 5  E0 2019-10-08 15:00:00         Watford          Brighton     0     3   A
# 6  E0 2019-10-08 17:30:00       Tottenham       Aston Villa     3     1   H
# 7  E0 2019-11-08 14:00:00       Leicester            Wolves     0     0   D
# 8  E0 2019-11-08 14:00:00       Newcastle           Arsenal     0     1   A
# 9  E0 2019-11-08 16:30:00      Man United           Chelsea     4     0   H
#
#    HTHG  HTAG HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     4     0   H  ...   7    5   9   9  11   2   0   2   0   0
# 1     0     1   A  ...   3    9   6  13   1   1   2   2   0   0
# 2     0     0   D  ...   3    3  10  19   3   4   2   1   0   0
# 3     0     0   D  ...   4    3   6  12   2   7   0   0   0   0
# 4     0     0   D  ...   2    3  16  14   6   2   2   1   0   1
# 5     0     1   A  ...   3    3  15  11   5   2   0   1   0   0
# 6     0     1   A  ...   7    4  13   9  14   0   1   0   0   0
# 7     0     0   D  ...   1    2   3  13  12   3   0   2   0   0
# 8     0     0   D  ...   2    2  12   7   5   3   1   3   0   0
# 9     1     0   H  ...   5    7  15  13   3   5   3   4   0   0
#
# [10 rows x 23 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       380 non-null    object
#  1   Date      380 non-null    datetime64[ns]
#  2   HomeTeam  380 non-null    object
#  3   AwayTeam  380 non-null    object
#  4   FTHG      380 non-null    int64
#  5   FTAG      380 non-null    int64
#  6   FTR       380 non-null    object
#  7   HTHG      380 non-null    int64
#  8   HTAG      380 non-null    int64
#  9   HTR       380 non-null    object
#  10  Referee   380 non-null    object
#  11  HS        380 non-null    int64
#  12  AS        380 non-null    int64
#  13  HST       380 non-null    int64
#  14  AST       380 non-null    int64
#  15  HF        380 non-null    int64
#  16  AF        380 non-null    int64
#  17  HC        380 non-null    int64
#  18  AC        380 non-null    int64
#  19  HY        380 non-null    int64
#  20  AY        380 non-null    int64
#  21  HR        380 non-null    int64
#  22  AR        380 non-null    int64
# dtypes: datetime64[ns](1), int64(16), object(6)
# memory usage: 68.4+ KB
# None

# %%
#collecting their unique values in a list and sorting it by name
team_list = matchdata["HomeTeam"].unique().tolist()
team_list.sort()

#these two items will start making sense after a while
home_team_df_list = []
away_team_df_list = []

# %%
# obtaining individual team dataframes played in home games, avoiding tracebacks from dropping a nonexistent column by using try/except structure
for team in team_list:
    home_actual_team = matchdata["HomeTeam"] == team
    home_actual_team_df = matchdata[home_actual_team]
    try:
        home_actual_team_df.drop("Referee",axis=1)
        home_team_df_list.append(home_actual_team_df) # putting dataframes in a list so that i can operate using the same index numbers with team_list to obtain individual teamdatas
    except:
        home_team_df_list.append(home_actual_team_df)
        continue

# %%
#and for away games:
for team in team_list:
    away_actual_team = matchdata["AwayTeam"] == team
    away_actual_team_df = matchdata[away_actual_team]
    try:
        away_actual_team_df.drop("Referee",axis=1)
        away_team_df_list.append(away_actual_team_df) # putting dataframes in a list so that i can operate using the same index numbers with team_list to obtain individual teamdatas
    except:
        away_team_df_list.append(away_actual_team_df)
        continue

# %%
print(home_team_df_list[:2]) #let's see the first three item in the list
# Out:
# [    Div                Date HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  \
# 10   E0 2019-08-17 12:30:00  Arsenal           Burnley     2     1   H     1
# 39   E0 2019-01-09 16:30:00  Arsenal         Tottenham     2     2   D     1
# 58   E0 2019-09-22 16:30:00  Arsenal       Aston Villa     3     2   H     0
# 76   E0 2019-06-10 14:00:00  Arsenal       Bournemouth     1     0   H     1
# 97   E0 2019-10-27 16:30:00  Arsenal    Crystal Palace     2     2   D     2
# 101  E0 2019-02-11 15:00:00  Arsenal            Wolves     1     1   D     1
# 121  E0 2019-11-23 15:00:00  Arsenal       Southampton     2     2   D     1
# 149  E0 2019-05-12 20:15:00  Arsenal          Brighton     1     2   A     0
# 168  E0 2019-12-15 16:30:00  Arsenal          Man City     0     3   A     0
# 196  E0 2019-12-29 14:00:00  Arsenal           Chelsea     1     2   A     1
# 207  E0 2020-01-01 20:00:00  Arsenal        Man United     2     0   H     2
# 220  E0 2020-01-18 15:00:00  Arsenal  Sheffield United     1     1   D     1
# 257  E0 2020-02-16 16:30:00  Arsenal         Newcastle     4     0   H     0
# 268  E0 2020-02-23 16:30:00  Arsenal           Everton     3     2   H     2
# 279  E0 2020-07-03 15:00:00  Arsenal          West Ham     1     0   H     0
# 314  E0 2020-01-07 18:00:00  Arsenal           Norwich     4     0   H     2
# 332  E0 2020-07-07 20:15:00  Arsenal         Leicester     1     1   D     1
# 354  E0 2020-07-15 20:15:00  Arsenal         Liverpool     2     1   H     2
# 370  E0 2020-07-26 16:00:00  Arsenal           Watford     3     2   H     3
#
#      HTAG HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 10      1   D  ...   9    5  13  11  10   7   2   1   0   0
# 39      2   A  ...   8    9  13  19  11   6   3   5   0   0
# 58      1   A  ...   6    9  13  15   9   4   5   1   1   0
# 76      0   H  ...   2    2  12   6  14   5   1   2   0   0
# 97      1   H  ...   6    4  18   9  12   5   2   0   0   0
# 101     0   H  ...   4    8   6  15   8   9   0   2   0   0
# 121     1   D  ...   5    6  13  19   6   8   6   2   0   0
# 149     1   A  ...   5    9  10  11   9   9   3   1   0   0
# 168     3   A  ...   1    7   9  24   3   3   1   4   0   0
# 196     0   H  ...   2    4  13  19   2   3   5   4   0   0
# 207     0   H  ...   4    4  11  15   1   4   2   0   0   0
# 220     0   H  ...   4    4   9  13   4   5   1   2   0   0
# 257     0   D  ...   7    2  15   9   5   6   2   0   0   0
# 268     2   D  ...   4    5  12  12   6   3   0   4   0   0
# 279     0   D  ...   2    6  11   9   6   7   1   2   0   0
# 314     0   H  ...   8    2  10  10   6   2   1   4   0   0
# 332     0   H  ...   7    5  10  14  10   1   1   0   1   0
# 354     1   H  ...   2    8  14  10   2  13   3   1   0   0
# 370     1   H  ...   5    6   9  12   4   8   3   3   0   0
#
# [19 rows x 23 columns],     Div                Date     HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 11   E0 2019-08-17 15:00:00  Aston Villa       Bournemouth     1     2   A
# 20   E0 2019-08-23 20:00:00  Aston Villa           Everton     2     0   H
# 49   E0 2019-09-16 20:00:00  Aston Villa          West Ham     0     0   D
# 61   E0 2019-09-28 15:00:00  Aston Villa           Burnley     2     2   D
# 81   E0 2019-10-19 15:00:00  Aston Villa          Brighton     2     1   H
# 102  E0 2019-02-11 15:00:00  Aston Villa         Liverpool     1     2   A
# 129  E0 2019-11-25 20:00:00  Aston Villa         Newcastle     2     0   H
# 155  E0 2019-08-12 14:00:00  Aston Villa         Leicester     1     4   A
# 171  E0 2019-12-21 15:00:00  Aston Villa       Southampton     1     3   A
# 180  E0 2019-12-26 15:00:00  Aston Villa           Norwich     1     0   H
# 218  E0 2020-12-01 16:30:00  Aston Villa          Man City     1     6   A
# 229  E0 2020-01-21 19:30:00  Aston Villa           Watford     2     1   H
# 256  E0 2020-02-16 14:00:00  Aston Villa         Tottenham     2     3   A
# 288  E0 2020-06-17 18:00:00  Aston Villa  Sheffield United     0     0   D
# 297  E0 2020-06-21 16:15:00  Aston Villa           Chelsea     1     2   A
# 310  E0 2020-06-27 12:30:00  Aston Villa            Wolves     0     1   A
# 339  E0 2020-09-07 20:15:00  Aston Villa        Man United     0     3   A
# 346  E0 2020-12-07 14:15:00  Aston Villa    Crystal Palace     2     0   H
# 367  E0 2020-07-21 20:15:00  Aston Villa           Arsenal     1     0   H
#
#      HTHG  HTAG HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 11      0     2   A  ...   7    4  10  13  10   5   0   2   0   0
# 20      1     0   H  ...   3    1  10  18   0   6   2   3   0   0
# 49      0     0   D  ...   5    1  13  12   2   4   2   1   0   1
# 61      1     0   H  ...   3    3  10  16   7   3   1   4   0   0
# 81      1     1   D  ...   8    5   9  17   7   5   1   2   0   1
# 102     1     0   H  ...   2    6  12   9   2  10   1   2   0   0
# 129     2     0   H  ...   8    5  10   9  11   6   1   1   0   0
# 155     1     2   A  ...   2    8  21  15   8   5   6   2   0   0
# 171     0     2   A  ...   6    8  16  15   7   5   2   1   0   0
# 180     0     0   D  ...   2    6  15  12   5   8   2   3   0   0
# 218     0     4   A  ...   1   12   5  12   2   4   2   1   0   0
# 229     0     1   A  ...   5    2  11  18   6   3   2   2   0   0
# 256     1     2   A  ...   4   10  12  10  12   7   2   0   0   0
# 288     0     0   D  ...   6    1  11  14  12   4   1   1   0   0
# 297     1     0   H  ...   4    5   9  17   2  10   2   1   0   0
# 310     0     0   D  ...   1    2  16  16   2   2   1   1   0   0
# 339     0     2   A  ...   1    6   7  13   3   5   2   3   0   0
# 346     1     0   H  ...   9    5  21  21   5   1   2   4   0   1
# 367     1     0   H  ...   3    0  13  19   8   9   2   4   0   0
#
# [19 rows x 23 columns]]

# %%
home_team_dict = {}
away_team_dict = {}
# putting every column's sum in a nested dictionary 
for a in range(len(team_list)):
    actual_home = home_team_df_list[a]
    #print(actual_home)
    start_point = actual_home.columns.get_loc("FTHG")
    add_dict = dict()
    for col in actual_home.iloc[:,start_point:]:

        #print(team_list[a])
        #print(col)
        val_sum = actual_home[col].sum()
        #print(val_sum)
        if type(val_sum) is str:
            continue
        add_dict["{}".format(col)] = val_sum
    #print(add_dict)
    home_team_dict[team_list[a]] = add_dict

# %%
for a in range(len(team_list)):
    actual_away = away_team_df_list[a]
    #print(actual_away)
    start_point = actual_away.columns.get_loc("FTHG")
    add_dict = dict()
    for col in actual_away.iloc[:,start_point:]:

        #print(team_list[a])
        #print(col)
        val_sum = actual_away[col].sum()
        #print(val_sum)
        if type(val_sum) is str:
            continue
        add_dict["{}".format(col)] = val_sum
    #print(add_dict)
    away_team_dict[team_list[a]] = add_dict

# these two nested dictionaries will return us teams' home and away statistics individually

# %%
print(home_team_dict)
# Out:
# {'Arsenal': {'FTHG': 36, 'FTAG': 24, 'HTHG': 21, 'HTAG': 14, 'HS': 231, 'AS': 285, 'HST': 91, 'AST': 105, 'HF': 221, 'AF': 252, 'HC': 128, 'AC': 108, 'HY': 42, 'AY': 38, 'HR': 2, 'AR': 0}, 'Aston Villa': {'FTHG': 22, 'FTAG': 30, 'HTHG': 11, 'HTAG': 16, 'HS': 249, 'AS': 275, 'HST': 80, 'AST': 90, 'HF': 231, 'AF': 276, 'HC': 111, 'AC': 102, 'HY': 34, 'AY': 38, 'HR': 0, 'AR': 3}, 'Bournemouth': {'FTHG': 22, 'FTAG': 30, 'HTHG': 9, 'HTAG': 16, 'HS': 199, 'AS': 277, 'HST': 61, 'AST': 90, 'HF': 172, 'AF': 236, 'HC': 102, 'AC': 125, 'HY': 36, 'AY': 39, 'HR': 2, 'AR': 1}, 'Brighton': {'FTHG': 20, 'FTAG': 27, 'HTHG': 8, 'HTAG': 12, 'HS': 236, 'AS': 224, 'HST': 68, 'AST': 77, 'HF': 186, 'AF': 180, 'HC': 103, 'AC': 97, 'HY': 27, 'AY': 32, 'HR': 1, 'AR': 0}, 'Burnley': {'FTHG': 24, 'FTAG': 23, 'HTHG': 7, 'HTAG': 11, 'HS': 220, 'AS': 233, 'HST': 81, 'AST': 78, 'HF': 211, 'AF': 203, 'HC': 95, 'AC': 107, 'HY': 30, 'AY': 22, 'HR': 0, 'AR': 1}, 'Chelsea': {'FTHG': 30, 'FTAG': 16, 'HTHG': 16, 'HTAG': 5, 'HS': 332, 'AS': 123, 'HST': 121, 'AST': 39, 'HF': 176, 'AF': 214, 'HC': 137, 'AC': 64, 'HY': 30, 'AY': 37, 'HR': 0, 'AR': 2}, 'Crystal Palace': {'FTHG': 15, 'FTAG': 20, 'HTHG': 4, 'HTAG': 8, 'HS': 231, 'AS': 218, 'HST': 68, 'AST': 82, 'HF': 207, 'AF': 251, 'HC': 111, 'AC': 109, 'HY': 34, 'AY': 39, 'HR': 1, 'AR': 5}, 'Everton': {'FTHG': 24, 'FTAG': 21, 'HTHG': 14, 'HTAG': 7, 'HS': 252, 'AS': 201, 'HST': 93, 'AST': 63, 'HF': 220, 'AF': 206, 'HC': 108, 'AC': 88, 'HY': 32, 'AY': 38, 'HR': 0, 'AR': 2}, 'Leicester': {'FTHG': 35, 'FTAG': 17, 'HTHG': 10, 'HTAG': 7, 'HS': 262, 'AS': 171, 'HST': 88, 'AST': 56, 'HF': 206, 'AF': 227, 'HC': 118, 'AC': 83, 'HY': 19, 'AY': 36, 'HR': 1, 'AR': 1}, 'Liverpool': {'FTHG': 52, 'FTAG': 16, 'HTHG': 29, 'HTAG': 7, 'HS': 314, 'AS': 172, 'HST': 129, 'AST': 58, 'HF': 156, 'AF': 170, 'HC': 144, 'AC': 92, 'HY': 13, 'AY': 27, 'HR': 1, 'AR': 0}, 'Man City': {'FTHG': 57, 'FTAG': 13, 'HTHG': 27, 'HTAG': 7, 'HS': 394, 'AS': 126, 'HST': 135, 'AST': 45, 'HF': 174, 'AF': 149, 'HC': 157, 'AC': 47, 'HY': 27, 'AY': 26, 'HR': 1, 'AR': 1}, 'Man United': {'FTHG': 40, 'FTAG': 17, 'HTHG': 21, 'HTAG': 9, 'HS': 299, 'AS': 163, 'HST': 118, 'AST': 61, 'HF': 223, 'AF': 217, 'HC': 96, 'AC': 85, 'HY': 29, 'AY': 38, 'HR': 0, 'AR': 0}, 'Newcastle': {'FTHG': 20, 'FTAG': 21, 'HTHG': 6, 'HTAG': 9, 'HS': 233, 'AS': 282, 'HST': 77, 'AST': 85, 'HF': 187, 'AF': 205, 'HC': 86, 'AC': 121, 'HY': 33, 'AY': 30, 'HR': 1, 'AR': 1}, 'Norwich': {'FTHG': 19, 'FTAG': 37, 'HTHG': 12, 'HTAG': 13, 'HS': 217, 'AS': 305, 'HST': 73, 'AST': 112, 'HF': 179, 'AF': 224, 'HC': 91, 'AC': 131, 'HY': 29, 'AY': 34, 'HR': 3, 'AR': 2}, 'Sheffield United': {'FTHG': 24, 'FTAG': 15, 'HTHG': 12, 'HTAG': 5, 'HS': 209, 'AS': 178, 'HST': 70, 'AST': 56, 'HF': 193, 'AF': 170, 'HC': 133, 'AC': 85, 'HY': 30, 'AY': 26, 'HR': 1, 'AR': 0}, 'Southampton': {'FTHG': 21, 'FTAG': 35, 'HTHG': 9, 'HTAG': 19, 'HS': 240, 'AS': 233, 'HST': 77, 'AST': 95, 'HF': 198, 'AF': 209, 'HC': 98, 'AC': 108, 'HY': 19, 'AY': 33, 'HR': 4, 'AR': 0}, 'Tottenham': {'FTHG': 36, 'FTAG': 17, 'HTHG': 19, 'HTAG': 10, 'HS': 246, 'AS': 239, 'HST': 79, 'AST': 79, 'HF': 209, 'AF': 206, 'HC': 110, 'AC': 88, 'HY': 39, 'AY': 36, 'HR': 2, 'AR': 1}, 'Watford': {'FTHG': 22, 'FTAG': 27, 'HTHG': 6, 'HTAG': 12, 'HS': 244, 'AS': 237, 'HST': 62, 'AST': 91, 'HF': 258, 'AF': 197, 'HC': 82, 'AC': 92, 'HY': 38, 'AY': 34, 'HR': 2, 'AR': 1}, 'West Ham': {'FTHG': 30, 'FTAG': 33, 'HTHG': 17, 'HTAG': 11, 'HS': 221, 'AS': 216, 'HST': 89, 'AST': 90, 'HF': 186, 'AF': 178, 'HC': 96, 'AC': 87, 'HY': 34, 'AY': 23, 'HR': 0, 'AR': 0}, 'Wolves': {'FTHG': 27, 'FTAG': 19, 'HTHG': 8, 'HTAG': 11, 'HS': 234, 'AS': 174, 'HST': 71, 'AST': 66, 'HF': 191, 'AF': 203, 'HC': 88, 'AC': 55, 'HY': 28, 'AY': 45, 'HR': 0, 'AR': 2}}

# %%
# storing them in a variable as DataFrames so wecan operate and visualize the data
home_team_df = pd.DataFrame(home_team_dict).transpose()
away_team_df = pd.DataFrame(away_team_dict).transpose()
print(home_team_df)
# Out:
#                   FTHG  FTAG  HTHG  HTAG   HS   AS  HST  AST   HF   AF   HC  \
# Arsenal             36    24    21    14  231  285   91  105  221  252  128
# Aston Villa         22    30    11    16  249  275   80   90  231  276  111
# Bournemouth         22    30     9    16  199  277   61   90  172  236  102
# Brighton            20    27     8    12  236  224   68   77  186  180  103
# Burnley             24    23     7    11  220  233   81   78  211  203   95
# Chelsea             30    16    16     5  332  123  121   39  176  214  137
# Crystal Palace      15    20     4     8  231  218   68   82  207  251  111
# Everton             24    21    14     7  252  201   93   63  220  206  108
# Leicester           35    17    10     7  262  171   88   56  206  227  118
# Liverpool           52    16    29     7  314  172  129   58  156  170  144
# Man City            57    13    27     7  394  126  135   45  174  149  157
# Man United          40    17    21     9  299  163  118   61  223  217   96
# Newcastle           20    21     6     9  233  282   77   85  187  205   86
# Norwich             19    37    12    13  217  305   73  112  179  224   91
# Sheffield United    24    15    12     5  209  178   70   56  193  170  133
# Southampton         21    35     9    19  240  233   77   95  198  209   98
# Tottenham           36    17    19    10  246  239   79   79  209  206  110
# Watford             22    27     6    12  244  237   62   91  258  197   82
# West Ham            30    33    17    11  221  216   89   90  186  178   96
# Wolves              27    19     8    11  234  174   71   66  191  203   88
#
#                    AC  HY  AY  HR  AR
# Arsenal           108  42  38   2   0
# Aston Villa       102  34  38   0   3
# Bournemouth       125  36  39   2   1
# Brighton           97  27  32   1   0
# Burnley           107  30  22   0   1
# Chelsea            64  30  37   0   2
# Crystal Palace    109  34  39   1   5
# Everton            88  32  38   0   2
# Leicester          83  19  36   1   1
# Liverpool          92  13  27   1   0
# Man City           47  27  26   1   1
# Man United         85  29  38   0   0
# Newcastle         121  33  30   1   1
# Norwich           131  29  34   3   2
# Sheffield United   85  30  26   1   0
# Southampton       108  19  33   4   0
# Tottenham          88  39  36   2   1
# Watford            92  38  34   2   1
# West Ham           87  34  23   0   0
# Wolves             55  28  45   0   2

# %%
print(away_team_df)
# Out:
#                   FTHG  FTAG  HTHG  HTAG   HS   AS  HST  AST   HF   AF   HC  \
# Arsenal             24    20    11     7  269  179   89   60  207  200  121
# Aston Villa         37    19     9     8  332  210   95   70  267  220  140
# Bournemouth         35    18    19    11  281  190  105   60  183  197  126
# Brighton            27    19    14     8  274  225   93   74  160  199  107
# Burnley             27    19    16     7  306  168   92   53  191  201  132
# Chelsea             38    39    16    20  199  293   78  102  183  210   69
# Crystal Palace      30    16    12     6  296  145   93   52  244  218  126
# Everton             35    20    16    13  226  218   85   69  204  252   94
# Leicester           24    32    13    14  209  275   81  102  233  212   92
# Liverpool           17    33     9    15  171  276   51  102  152  175   68
# Man City            22    45    10    21  153  351   70  128  163  187   51
# Man United          19    26     8    14  224  244   67   98  233  210  101
# Newcastle           37    18    14    10  285  162  115   54  229  183  131
# Norwich             38     7    22     2  300  191  102   58  220  184  135
# Sheffield United    24    15    10     4  252  145   84   45  156  217  133
# Southampton         25    30     9    13  219  260   73  104  205  252  115
# Tottenham           30    25    12    13  297  199  104   81  236  214  119
# Watford             37    14    20     9  263  180   92   58  159  226  109
# West Ham            29    19    11     8  285  196   99   74  178  201  132
# Wolves              21    24    15     6  222  225   63   74  181  215   93
#
#                    AC  HY  AY  HR  AR
# Arsenal           103  41  44   1   3
# Aston Villa        89  40  34   4   1
# Bournemouth        92  28  37   2   1
# Brighton           75  29  29   1   1
# Burnley            76  17  37   2   0
# Chelsea           110  39  30   1   0
# Crystal Palace     66  42  27   0   1
# Everton            95  21  38   0   3
# Leicester         104  31  22   2   2
# Liverpool         114  20  25   0   0
# Man City          141  27  33   0   3
# Man United        108  39  43   2   0
# Newcastle          65  25  32   1   2
# Norwich            71  22  38   0   0
# Sheffield United   79  19  31   0   1
# Southampton       112  32  34   3   0
# Tottenham          90  44  43   0   1
# Watford            85  31  37   0   1
# West Ham           94  21  28   0   1
# Wolves            105  35  29   3   2

# %%
general_team_fig = plt.figure(figsize=(6,12))
general_team = general_team_fig.add_subplot(1,1,1)
goals_scored_h = home_team_df.iloc[:,0]
labels= goals_scored_h.keys()
vals = goals_scored_h.values
general_team.barh(range(len(labels)),vals, tick_label=labels, height=0.7)
general_team.set_title("Home goals scored")
plt.show()
